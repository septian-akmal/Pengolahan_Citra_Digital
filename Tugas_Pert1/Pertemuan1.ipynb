# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
img = cv2.imread('/content/Saya.jpeg')

# %%
cv2_imshow(img)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img1 = cv2.imread('/content/Saya.jpeg',0)
cv2_imshow(img1)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
img = cv2.imread('/content/Saya.jpeg')		
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)		

plt.imshow(rgb_img)
plt.show()

# %%
img = cv2.imread('/content/Saya.jpeg',0)		
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)		

plt.imshow(rgb_img)
plt.show()

# %%
cv2.imwrite('gambar1.png',img1)
# Out:
# True
